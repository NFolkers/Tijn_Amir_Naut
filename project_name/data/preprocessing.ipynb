# %% [markdown]
# ## **Preprocessing**
#
# As a start, we'll make some visualizations of the data

# %%
import os
import numpy as np
import pandas as pd
import mnist_reader
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
user = 'tinus'
mpl.rcParams['figure.figsize'] = (12, 8)

if user == 'tinus':
    wd_data = r"c:\Users\vwold\Documents\24_MLP\Tijn_Amir_Naut\data"

# %%
u_train, y_train = mnist_reader.load_mnist(wd_data, kind = 'train')
u_test, y_test = mnist_reader.load_mnist(wd_data, kind = 't10k')

# %%
print(y_train.shape)
# Out:
# (60000,)

# %%
print(pd.DataFrame(y_train).value_counts())
# Out:
# 0    6000
# 1    6000
# 2    6000
# 3    6000
# 4    6000
# 5    6000
# 6    6000
# 7    6000
# 8    6000
# 9    6000
# Name: count, dtype: int64

# %%
def set_style():
    sns.set_style('whitegrid')
    sns.set_palette('Set2')
    sns.set_context('notebook', font_scale = 1.5, rc = {'lines.linewidth': 2.5})


def plot_label_distribution(data):
    set_style()

    sns.histplot(data, discrete = True)
    plt.title('Label distribution pf the Fashion MNIST training dataset')
    plt.xlabel('Label')
    plt.ylabel('Frequency count')
    plt.show()


plot_label_distribution(y_train)

# %%
# def plot_pixel_intensities(data):
#     set_style()

#     sns.histplot(data.flatten())
#     plt.show()


# plot_pixel_intensities(u_train)
